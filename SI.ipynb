# %%
a=int(input("Enter first number"))
b=int(input("Enter second number"))
num=int(input("Enter a number to perform the operations"))
match num:
    case 1:
        print("Additon =",a+b)
    case 2:
        print("Subtraction=",a-b)
    case 3:
        print("Multiplication=",a*b)
    case 4:
        print("Diviaion=",a/b)
    case 5:
        print("Modulus=",a%b)
# Out:
# Enter first number 4
# Enter second number 6
# Enter a number to perform the operations 9
