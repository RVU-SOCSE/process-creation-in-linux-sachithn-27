# %%
print("1.Celsius to Fahrenheit")
print("2.Fahrenheit tp celsius")
ch=int(input("Enter 1/2"))
t=float(input("Enter temperature value"))
if ch==1:
    result= (t*9/5) + 32
else:
    result = (t-32)*5/9
print(result)
# Out:
# 1.Celsius to Fahrenheit
# 2.Fahrenheit tp celsius
# Enter 1/2 1
# Enter temperature value 22
# 71.6
